# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/farrukhrahimsandhu/flyrank-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# Task Type: Classification.
#
# Why: We want to categorize web pages into specific buckets—specifically, classifying whether a page belongs to the "needs refresh" class (declining traffic) or the "fine as is" class.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# Target: We will predict the trend_direction (specifically looking for the 'down' label).
#
# Where it comes from: This label comes from an observed outcome (actual historical traffic data showing the page is losing clicks), rather than a made-up rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# Metric: Precision.
#
# Why: A high precision number means "when the model flags a page for a rewrite, it is almost always right." This is 'good' because we do not want to waste expensive human writer time updating pages that were already doing perfectly fine.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

# Load the specific slice of data for the Content Refresh lane
url = 'https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(url)

print("Our unit of analysis is ONE WEB PAGE per row.")
print(f"Total rows in this dataset: {len(df)}")
print("\nHere is a look at the first 3 rows to show our target column:")
df.head(3)
# Out:
# Our unit of analysis is ONE WEB PAGE per row.
# Total rows in this dataset: 30000
#
# Here is a look at the first 3 rows to show our target column:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# 0     20457.0  ...     15000-25000  0.76          10.6             5.88
# 1     15562.0  ...     15000-25000  0.05          20.3             0.00
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# Why ML: A simple if-statement like IF content_age_days > 365 THEN refresh is too messy and misses the big picture. Some old pages are evergreen and do great, while some new pages fail quickly. Machine Learning can weigh age, click-through rate, and word count all at the exact same time to find complex patterns a human rule would miss.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
