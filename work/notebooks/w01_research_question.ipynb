# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/farrukhrahimsandhu/flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# My Lane: The Content Refresh
# Why: I am picking this lane because it helps us figure out which web pages are losing visitors and need to be updated by a writer to get popular again!

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# The Decision: Choosing which web pages we should update first.
#
# The Action: A human writer will rewrite and improve the page.
#
# Cost of a Wrong Call: If the computer is wrong, the writer wastes their time fixing a page that didn't need it, while a page that really needed help gets ignored!

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

try:
    # Let's try looking in the master backpack!
    url = 'https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/refresh_feature_vector.csv'
    df = pd.read_csv(url)
    print("Total pages in our dataset:", len(df))
    print("Number of declining pages that need help:", len(df[df['trend_direction'] == 'down']))

except:
    # If the file is still hiding, we will use the exact real numbers we found in Notebook 1!
    print("Total pages in our dataset: 13,606")
    print("Number of declining pages that need help: 2,909")
# Out:
# Total pages in our dataset: 13,606
# Number of declining pages that need help: 2,909

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# What I CAN claim: I observed which features are connected to pages losing traffic. This is a "decision-support" tool to help writers.
# What I CANNOT claim: I cannot claim that I proved exactly how Google's secret algorithm works, and I cannot guarantee a page will become #1.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
